# %% [markdown]
# # DRILL:
#
# Implement a binary tree, which is filled with 15 pieces of random data. Your job is to then write a program to traverse the tree using a breadth first traversal. If you want additional practice, try other forms of traversal.

# %%
# define class node for leaves of tree
class Node:
    def __init__(self, val):
        self.left = None
        self.right = None
        self.val = val

    # get height of a tree--the number of nodes along the longest path from the root node down to 
    ## the farthest leaf node 
    def height(node):
        h=0
        if node is None: 
            return 0 
        else : 
            if node==root:
                h=h
            elif node==root.left or root.right:
                h=+1
            elif node==root.left.left or root.left.right or root.right.left or root.right.right:
                h=+2
            elif node==root.left.left.left or root.left.left.right or root.left.right.left or root.left.right.right or root.right.left.left or root.right.left.left or root.right.right.left or root.right.right.right:
                h=+3
    def place(node, h):
        if node is None:
            return 0
        else:
            # get placement in row of tree
            if h==0:
                print('A')
            if h==1:
                if node==root.left:
                    print('B')
                elif node==root.right:
                    print('C')
            if h==2:
                if node==root.left.left:
                    print('D')
                elif node==root.left.right:
                    print('E')
                elif node==root.right.left:
                    print('F')
                elif node ==root.right.right:
                    print('G')
            if h==3:
                if node==root.left.left.left:
                    print('H')
                elif node==root.left.left.right:
                    print('I')
                elif node==root.left.right.left:
                    print('J')
                elif node==root.left.right.right:
                    print('K')
                elif node==root.right.left.left:
                    print('L')
                elif node==root.right.left.left:
                    print('M')
                elif node==root.right.right.left:
                    print('N')
                elif node==root.right.right.right:
                    print('O')
    
# Establish the initial root node and children
root = Node('A')
root.left = Node('B')
root.right = Node('C')

# Add the appropriate children for B and
root.left.left = Node('D')
root.left.right = Node('E')
root.right.left = Node('F')
root.right.right = Node('G')
    
# Add the appropriate children for D, E, F, G
root.left.left.left = Node('H')
root.left.left.right = Node('I')
root.left.right.left = Node('J')
root.left.right.right = Node('K')
root.right.left.left = Node('L')
root.right.left.left = Node('M')
root.right.right.left = Node('N')
root.right.right.right = Node('O')

# %%
# create tuple of node place and height
node_tuple=[(root, 0), (root.left, 1), (root.left.left, 2), (root.left.left.left, 3), (root.left.left.right, 3), 
            (root.left.right, 2), (root.left.right.left, 3), (root.left.right.right, 3), (root.right, 1), 
            (root.right.left, 2), (root.right.left.left, 3), (root.right.left.right, 3), (root.right.right, 2),
            (root.right.right.left, 3), (root.right.right.right, 3)]
# iterate through tuple to print traversal
for node, h in node_tuple:
    Node.place(node, h)
# Out:
# A
# B
# D
# H
# I
# E
# J
# K
# C
# F
# L
# G
# N
# O
